# %% [markdown]
# # Tarea 2
# ### Roberto Alejandro García De La O
#
# Ubicacion de reviews.csv en https://github.com/AlexG1991/tarea2_reviews.git

# %%
import pandas as pd
import numpy as np
import re
import nltk
nltk.download('wordnet')
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from collections import Counter

df_reviews = pd.read_csv('reviews.csv') # read in the csv file
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rgarciad\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
FrecResult = df_reviews['rating'].value_counts().reindex([10, 20, 30,40,50])
ax = FrecResult.plot.bar(title="Distribución de Rating")

# %%
print("Estadísticas de rating")
df_reviews.describe()
# Out:
# Estadísticas de rating
#               rating
# count  196649.000000
# mean       38.539072
# std        11.570687
# min        10.000000
# 25%        30.000000
# 50%        40.000000
# 75%        50.000000
# max        50.000000

# %%
print("La media es " + str(df_reviews['rating'].mean()))
print("La mediana es " + str(df_reviews['rating'].median()))
print("La desviación estándar es " + str(df_reviews['rating'].std()))
# Out:
# La media es 38.53907215393925
# La mediana es 40.0
# La desviación estándar es 11.57068676760231

# %%
list_reviews = []
for review in df_reviews["review"]:
    list_reviews.append(review)

# %%
#palabras, stems y lems de todos los reviews
vocabulario = set()
tokens = []
stems = set()
lems = set()

for review in list_reviews:
    text_lower = review.lower()
    words = re.split('\W+', text_lower)
    for word in words:
        vocabulario.add(word)
        tokens.append(word)
        
count_words = len(vocabulario)


#vocabulario stems
ps = PorterStemmer()
for token in tokens:
    stems.add(ps.stem(token))

count_stems = len(stems)

#vocabulario lemas

lemmatizer = WordNetLemmatizer()
for token in tokens:
    lems.add(lemmatizer.lemmatize(token))

count_lems = len(lems)

# %%
print("Total de reviews")
print("El total de palabras es " + str(count_words))
print("El total de stems es " + str(count_stems))
print("El total de lemas es " + str(count_lems))
# Out:
# Total de reviews
# El total de palabras es 87659
# El total de stems es 65925
# El total de lemas es 82200

# %%
#palabras, stems y lems de todos los reviews de 1 estrella
list_reviews = []
for review in df_reviews[df_reviews["rating"] == 10]["review"]:
    list_reviews.append(review)

vocabulario = set()
tokens = []
stems = set()
lems = set()

for review in list_reviews:
    text_lower = review.lower()
    words = re.split('\W+', text_lower)
    for word in words:
        vocabulario.add(word)
        tokens.append(word)
        
count_words = len(vocabulario)


#vocabulario stems
ps = PorterStemmer()
for token in tokens:
    stems.add(ps.stem(token))

count_stems = len(stems)

#vocabulario lemas

lemmatizer = WordNetLemmatizer()
for token in tokens:
    lems.add(lemmatizer.lemmatize(token))

count_lems = len(lems)

counts = Counter(tokens)

print("Total de reviews de 1 estrella")
print("El total de palabras es " + str(count_words))
print("El total de stems es " + str(count_stems))
print("El total de lemas es " + str(count_lems))
print("Bag or words:")
print(counts)
# Out:
# Total de reviews de 1 estrella
# El total de palabras es 26848
# El total de stems es 19355
# El total de lemas es 24548
# Bag or words:
# ...

# %%
#palabras, stems y lems de todos los reviews de 2 estrellas
list_reviews = []
for review in df_reviews[df_reviews["rating"] == 20]["review"]:
    list_reviews.append(review)

vocabulario = set()
tokens = []
stems = set()
lems = set()

for review in list_reviews:
    text_lower = review.lower()
    words = re.split('\W+', text_lower)
    for word in words:
        vocabulario.add(word)
        tokens.append(word)
        
count_words = len(vocabulario)


#vocabulario stems
ps = PorterStemmer()
for token in tokens:
    stems.add(ps.stem(token))

count_stems = len(stems)

#vocabulario lemas

lemmatizer = WordNetLemmatizer()
for token in tokens:
    lems.add(lemmatizer.lemmatize(token))

count_lems = len(lems)

counts = Counter(tokens)

print("Total de reviews de 2 estrellas")
print("El total de palabras es " + str(count_words))
print("El total de stems es " + str(count_stems))
print("El total de lemas es " + str(count_lems))
print("Bag or words:")
print(counts)
# Out:
# Total de reviews de 2 estrellas
# El total de palabras es 23901
# El total de stems es 17005
# El total de lemas es 21711
# Bag or words:
# ...

# %%
#palabras, stems y lems de todos los reviews de 3 estrellas
list_reviews = []
for review in df_reviews[df_reviews["rating"] == 30]["review"]:
    list_reviews.append(review)

vocabulario = set()
tokens = []
stems = set()
lems = set()

for review in list_reviews:
    text_lower = review.lower()
    words = re.split('\W+', text_lower)
    for word in words:
        vocabulario.add(word)
        tokens.append(word)
        
count_words = len(vocabulario)


#vocabulario stems
ps = PorterStemmer()
for token in tokens:
    stems.add(ps.stem(token))

count_stems = len(stems)

#vocabulario lemas

lemmatizer = WordNetLemmatizer()
for token in tokens:
    lems.add(lemmatizer.lemmatize(token))

count_lems = len(lems)

counts = Counter(tokens)

print("Total de reviews de 3 estrellas")
print("El total de palabras es " + str(count_words))
print("El total de stems es " + str(count_stems))
print("El total de lemas es " + str(count_lems))
print("Bag or words:")
print(counts)
# Out:
# Total de reviews de 3 estrellas
# El total de palabras es 34082
# El total de stems es 24643
# El total de lemas es 31233
# Bag or words:
# ...

# %%
#palabras, stems y lems de todos los reviews de 4 estrellas
list_reviews = []
for review in df_reviews[df_reviews["rating"] == 40]["review"]:
    list_reviews.append(review)

vocabulario = set()
tokens = []
stems = set()
lems = set()

for review in list_reviews:
    text_lower = review.lower()
    words = re.split('\W+', text_lower)
    for word in words:
        vocabulario.add(word)
        tokens.append(word)
        
count_words = len(vocabulario)


#vocabulario stems
ps = PorterStemmer()
for token in tokens:
    stems.add(ps.stem(token))

count_stems = len(stems)

#vocabulario lemas

lemmatizer = WordNetLemmatizer()
for token in tokens:
    lems.add(lemmatizer.lemmatize(token))

count_lems = len(lems)

counts = Counter(tokens)

print("Total de reviews de 4 estrellas")
print("El total de palabras es " + str(count_words))
print("El total de stems es " + str(count_stems))
print("El total de lemas es " + str(count_lems))
print("Bag or words:")
print(counts)
# Out:
# Total de reviews de 4 estrellas
# El total de palabras es 46999
# El total de stems es 34768
# El total de lemas es 43473
# Bag or words:
# ...

# %%
#palabras, stems y lems de todos los reviews de 5 estrellas
list_reviews = []
for review in df_reviews[df_reviews["rating"] == 50]["review"]:
    list_reviews.append(review)

vocabulario = set()
tokens = []
stems = set()
lems = set()

for review in list_reviews:
    text_lower = review.lower()
    words = re.split('\W+', text_lower)
    for word in words:
        vocabulario.add(word)
        tokens.append(word)
        
count_words = len(vocabulario)


#vocabulario stems
ps = PorterStemmer()
for token in tokens:
    stems.add(ps.stem(token))

count_stems = len(stems)

#vocabulario lemas

lemmatizer = WordNetLemmatizer()
for token in tokens:
    lems.add(lemmatizer.lemmatize(token))

count_lems = len(lems)

counts = Counter(tokens)

print("Total de reviews de 5 estrellas")
print("El total de palabras es " + str(count_words))
print("El total de stems es " + str(count_stems))
print("El total de lemas es " + str(count_lems))
print("Bag or words:")
print(counts)
# Out:
# Total de reviews de 5 estrellas
# El total de palabras es 45689
# El total de stems es 34254
# El total de lemas es 42359
# Bag or words:
# ...
